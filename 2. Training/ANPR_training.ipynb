# %%
### 1. Mount Google Drive ###

from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
### 2. Define root directory ###

ROOT_DIR = '/content/gdrive/MyDrive/ANPR'

# %%
### 3. Install Ultralytics ###

# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 9.7 MB/s eta 0:00:00
# ...

# %%
### 4. Train model ###

import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8s.pt")  # load pre trained model

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "number-plate.yaml"), epochs=30)  # train the model
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#5. copy results
import shutil

source_dir = '/content/runs'  # Source directory
destination_dir = '/content/gdrive/MyDrive/ANPR/res'  # Destination directory in Google Drive

shutil.copytree(source_dir, destination_dir)
# Out:
# '/content/gdrive/MyDrive/ANPR/res'
